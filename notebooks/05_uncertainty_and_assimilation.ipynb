# %% [markdown]
# # 05 Uncertainty and Assimilation
#
# Sketch posterior-style interaction intervals and observation-updated ecosystem states.

# %%
import numpy as np
from agroecosim.inference.bayesian_glv import BayesianGLV

species = ['crop', 'pest', 'bird']
means = np.array([[0.0, -0.02, 0.0], [0.01, 0.0, -0.03], [0.0, 0.02, 0.0]])
sds = np.full((3, 3), 0.006)
BayesianGLV().summarize_interactions(species, means, sds)[:3]
