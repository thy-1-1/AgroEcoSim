# %% [markdown]
# # 04 Scenario Decision Matrix
#
# Compare conventional, chemical-withdrawal, biological-control, and organic-transition pathways.

# %%
import pandas as pd

summary = pd.read_csv('../results/tables/scenario_summary.csv')
summary.sort_values('stability_score', ascending=False)
