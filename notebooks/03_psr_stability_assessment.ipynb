# %% [markdown]
# # 03 PSR Stability Assessment
#
# Estimate entropy weights and composite ecosystem stability scores.

# %%
from agroecosim.data.pipeline import synthetic_indicator_sample, build_indicator_frame
from agroecosim.models.psr_evaluation import PSREvaluator

indicators = build_indicator_frame(synthetic_indicator_sample())
result = PSREvaluator().score(indicators)
result.scores.tail(), result.weights.sort_values(ascending=False)
