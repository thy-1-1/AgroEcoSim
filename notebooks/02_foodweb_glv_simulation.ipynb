# %% [markdown]
# # 02 Food-Web gLV Simulation
#
# Simulate crop, pest, predator, pollinator, and soil-biota dynamics through a generalized Lotka-Volterra interface.

# %%
import numpy as np
from agroecosim.models.glv_foodweb import demo_foodweb

model = demo_foodweb()
trajectory = model.simulate(np.array([100, 50, 5, 3, 12, 80]), horizon=365, steps=365)
trajectory.tail()
