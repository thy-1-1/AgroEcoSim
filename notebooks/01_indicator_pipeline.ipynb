# %% [markdown]
# # 01 Indicator Pipeline
#
# Construct PSR-ready ecological indicators from crop, chemical, biomass, and resilience signals.

# %%
from agroecosim.data.pipeline import synthetic_indicator_sample, build_indicator_frame

raw = synthetic_indicator_sample(periods=12)
indicators = build_indicator_frame(raw)
indicators.head()
